# %%
from scipy import misc
from skimage.io import imread, imshow
from skimage.transform import resize, rescale 
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %%
def colorDist(x,  y):   
    dist = []
    for row in y:
        dist.append((sum((x-row)**2)))
    dist = np.array(dist)
    return dist

def showColors(centres_colors): # Shows current colors of clusters' centres
    height = 10
    width = 3
    colors_image = np.ndarray((height, width*len(centres_colors), 3), dtype=np.uint8)
    sorted_colors = centres_colors.copy()
    ind = np.lexsort((sorted_colors[:,2], sorted_colors[:,1], sorted_colors[:,0]))
    sorted_colors = [sorted_colors[i] for i in ind]
        
    for i in range(height):
        for j in range(width*len(centres)):
            colors_image[i][j] = sorted_colors[j//width]
    imshow(colors_image)
    plt.show()
    
def segmentation(image, centres):
    
    xSize = image.shape[0]
    ySize = image.shape[1]
    labels = np.array((xSize, ySize), dtype=int) #For each point we store it's cluster
    centres_old = np.zeros(centres.shape)
    centres_colors = [image[center[0]][center[1]] for center in centres]
    centres_colors = np.array(centres_colors)
    centres_colors = centres_colors.astype(int)

    labels = np.zeros((xSize, ySize), dtype=int)

    for iteration in range(5):
        for i in range(xSize):
            for j in range(ySize):
                distances = colorDist(image[i][j], centres_colors)
                cluster = np.argmin(distances)
                labels[i][j] = cluster
    
        for c in range(k):
            points = [image[i][j].astype(int) for i in range(xSize) for j in range(ySize) if labels[i][j] == c]
            centres_colors[c] = np.mean(points, axis=0)
        
        showColors(centres_colors)    
    
    imgCopy = image.copy()
    for i in range(xSize):
        for j in range(ySize):
            cluster = labels[i][j]
            imgCopy[i][j] = centres_colors[cluster]
    imshow(imgCopy)
    plt.show()

# %% [markdown]
# ## Ball image

# %%
IMAGE = 'ball.jpg'
image = imread(IMAGE, plugin ='matplotlib')
imshow(image)
print(image.shape)
plt.show()
# Out:
# (160, 240, 3)
# /home/pavel/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
k = 10 #clusters number
C_x = np.random.randint(0, image.shape[0], size=k)
# Y coordinates of random centroids
C_y = np.random.randint(0, image.shape[1], size=k)
centres = np.array(list(zip(C_x, C_y)), dtype=np.int64)

# %%
segmentation(image, centres)
# Out:
# /home/pavel/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %% [markdown]
# ## Cat Image

# %%
from PIL import Image

image = Image.open('cat.png')
image = image.convert('RGB')
image.save('catRGB.jpg')
IMAGE = 'catRGB.jpg'
image = imread(IMAGE, plugin ='matplotlib')
imshow(image)
plt.show()
# Out:
# /home/pavel/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
k = 7 #clusters number
C_x = np.random.randint(0, image.shape[0], size=k)
# Y coordinates of random centroids
C_y = np.random.randint(0, image.shape[1], size=k)
centres = np.array(list(zip(C_x, C_y)), dtype=np.int64)

# %%
segmentation(image, centres)
# Out:
# /home/pavel/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/pavel/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/pavel/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %% [markdown]
# ## Landscape image

# %%
IMAGE = 'landscape.jpg'
image = imread(IMAGE, plugin ='matplotlib')
imshow(image)
plt.show()
# Out:
# /home/pavel/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
k = 15 #clusters number
C_x = np.random.randint(0, image.shape[0], size=k)
# Y coordinates of random centroids
C_y = np.random.randint(0, image.shape[1], size=k)
centres = np.array(list(zip(C_x, C_y)), dtype=np.int64)

# %%
segmentation(image, centres)
# Out:
# /home/pavel/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/pavel/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/pavel/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %% [markdown]
# ## Plane Image

# %%
IMAGE = 'plane.jpg'
image = imread(IMAGE, plugin ='matplotlib')
imshow(image)
plt.show()
# Out:
# /home/pavel/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
k = 10 #clusters number
C_x = np.random.randint(0, image.shape[0], size=k)
# Y coordinates of random centroids
C_y = np.random.randint(0, image.shape[1], size=k)
centres = np.array(list(zip(C_x, C_y)), dtype=np.int64)

# %%
segmentation(image, centres)
# Out:
# /home/pavel/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/pavel/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/pavel/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %% [markdown]
# ## Sky image

# %%
IMAGE = 'sky.jpg'
image = imread(IMAGE, plugin ='matplotlib')
imshow(image)
plt.show()
# Out:
# /home/pavel/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
k = 10 #clusters number
C_x = np.random.randint(0, image.shape[0], size=k)
# Y coordinates of random centroids
C_y = np.random.randint(0, image.shape[1], size=k)
centres = np.array(list(zip(C_x, C_y)), dtype=np.int64)

# %%
segmentation(image, centres)
# Out:
# /home/pavel/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
